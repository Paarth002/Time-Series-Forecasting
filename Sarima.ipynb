# %%
from google.colab import drive
drive.mount('/content/drive/',force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd
import numpy as np
import os

# %%
data = pd.read_csv('/content/drive/MyDrive/datathon resources/Train Set - Train Set.csv')

# %%
# data= pd.read_csv("/content/drive/MyDrive/Train Set.csv")

# %%
data.head()
# Out:
#   Region_Name   Month 1   Month 2  ...  Month 70  Month 71  Month 72
# 0    Region 1  0.154324  0.122901  ...  0.373754  0.333642  0.242176
# 1    Region 2  0.119708  0.119831  ...  0.344997  0.300503  0.215147
# 2    Region 3  0.178236  0.165497  ...  0.400269  0.360406  0.335923
# 3    Region 4  0.225016  0.220602  ...  0.364874  0.311379  0.271102
# 4    Region 5  0.318976  0.316835  ...  0.416527  0.372523  0.392835
#
# [5 rows x 73 columns]

# %%
data2=data.drop('Region_Name',axis=1)
data2=data2.T
data2.head(5)
# Out:
#              0         1         2     ...      3912      3913      3914
# Month 1  0.154324  0.119708  0.178236  ...  0.463527  1.641510  0.307089
# Month 2  0.122901  0.119831  0.165497  ...  0.571315  1.649937  0.451604
# Month 3  0.127583  0.112970  0.190754  ...  0.644025  2.110449  0.448063
# Month 4  0.501557  0.326049  0.321733  ...  0.636814  1.642345  0.464692
# Month 5  0.103551  0.098852  0.203126  ...  0.496774  1.002016  0.384780
#
# [5 rows x 3915 columns]

# %%
col_max =[]
for column in data2.columns:
        col_max.append(data2[column].abs().max())
        data2[column] = data2[column] / data2[column].abs().max()

# %%
data2=data2.T
data2.head()
# Out:
#     Month 1   Month 2   Month 3  ...  Month 70  Month 71  Month 72
# 0  0.296752  0.236327  0.245330  ...  0.718693  0.641562  0.465681
# 1  0.238358  0.238603  0.224942  ...  0.686945  0.598350  0.428392
# 2  0.309499  0.287378  0.331235  ...  0.695046  0.625827  0.583313
# 3  0.359831  0.352774  0.358591  ...  0.583485  0.497939  0.433530
# 4  0.474231  0.471049  0.488370  ...  0.619263  0.553842  0.584040
#
# [5 rows x 72 columns]

# %%
# specify training data
train = data2
# test = data2

# %%
print(data2.shape, train.shape)
# Out:
# (3915, 72) (3915, 72)

# %%
def loss(test,predicted):
  n=len(test)
  sum1=0
  for x in range(n):
    sum1=sum1+((test[x]-predicted[x])**2)
  sum1=sum1/n
  return sum1

# %%
# !pip install statsmodels
import statsmodels.api as sm
# Out:
# ...
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
col = ['Month 73', 'Month 74', 'Month 75', 'Month 76', 'Month 77', 'Month 78', 'Month 79', 'Month 80', 'Month 81', 'Month 82', 'Month 83', 'Month 84', 'Month 85', 'Month 86', 'Month 87']
ind = []
for i in range(1, 3916):
  s = 'Region '+ str(i)
  ind.append(s)
df = pd.DataFrame(columns=col, index=ind)

# %%
print(df)
# Out:
#             Month 73 Month 74 Month 75  ... Month 85 Month 86 Month 87
# Region 1         NaN      NaN      NaN  ...      NaN      NaN      NaN
# Region 2         NaN      NaN      NaN  ...      NaN      NaN      NaN
# Region 3         NaN      NaN      NaN  ...      NaN      NaN      NaN
# Region 4         NaN      NaN      NaN  ...      NaN      NaN      NaN
# Region 5         NaN      NaN      NaN  ...      NaN      NaN      NaN
# ...              ...      ...      ...  ...      ...      ...      ...
# Region 3911      NaN      NaN      NaN  ...      NaN      NaN      NaN
# Region 3912      NaN      NaN      NaN  ...      NaN      NaN      NaN
# Region 3913      NaN      NaN      NaN  ...      NaN      NaN      NaN
# Region 3914      NaN      NaN      NaN  ...      NaN      NaN      NaN
# Region 3915      NaN      NaN      NaN  ...      NaN      NaN      NaN
#
# [3915 rows x 15 columns]

# %%
# define model configuration
my_order = (1, 1, 1)
my_seasonal_order = (1, 1, 1, 6)
main_lst = []
# define model
# total_loss=0
for i in range(3915): #change 1 to 3915 for training complete dataset
  model=sm.tsa.statespace.SARIMAX(train.iloc[i],order=(1, 1, 1),seasonal_order=(1,1,1,6))
  results=model.fit()
  z = results.predict(start=73,end=87,dynamic=False)
  s = 'Region ' + str(i+1)
  df.loc[s] = list(z)
  # total_loss = total_loss + loss(list(test.iloc[0]), list(z))

# print(total_loss/1)
# Out:
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ...

# %%
print(df)
# Out:
#              Month 73  Month 74  Month 75  ...  Month 85  Month 86  Month 87
# Region 1     0.483984  0.569824  0.707482  ...  0.519555  0.599551  0.734992
# Region 2     0.450358  0.573319  0.656666  ...  0.489855  0.609177  0.692261
# Region 3     0.534883  0.630853  0.708814  ...  0.573757  0.669346  0.748609
# Region 4      0.42396  0.503759  0.570441  ...  0.440594  0.517337  0.581788
# Region 5     0.476522  0.547195  0.624225  ...  0.476765  0.547792  0.624381
# ...               ...       ...       ...  ...       ...       ...       ...
# Region 3911  0.673637  0.691704  0.672415  ...  0.655013  0.657675   0.68997
# Region 3912   0.69177  0.860597  0.888983  ...  0.695001  0.834044  0.935446
# Region 3913  0.475149  0.505325     0.605  ...  0.366056    0.4148  0.567143
# Region 3914  0.521339  0.561862  0.552203  ...  0.400716  0.439152  0.488189
# Region 3915  0.485107  0.539438  0.680755  ...  0.439011  0.496688  0.658414
#
# [3915 rows x 15 columns]

# %%
for i in range(3915):
  s = 'Region ' + str(i+1)
  df.loc[s] *= col_max[i]

# %%
print(df)
# Out:
#              Month 73  Month 74  Month 75  ...  Month 85  Month 86  Month 87
# Region 1     0.251694  0.296335  0.367923  ...  0.270193  0.311794   0.38223
# Region 2     0.226178  0.287932   0.32979  ...  0.246015   0.30594  0.347667
# Region 3     0.308033    0.3633  0.408197  ...   0.33042  0.385469  0.431115
# Region 4     0.265117  0.315019  0.356718  ...   0.27552   0.32351  0.363813
# Region 5     0.320517  0.368053  0.419864  ...   0.32068  0.368454  0.419969
# ...               ...       ...       ...  ...       ...       ...       ...
# Region 3911    2.9981   3.07851   2.99266  ...   2.91521   2.92706   3.07079
# Region 3912   0.77358  0.962373  0.994117  ...  0.777194   0.93268   1.04607
# Region 3913  0.721403  0.767218  0.918551  ...  0.555771  0.629778  0.861074
# Region 3914    1.3267   1.42983   1.40525  ...   1.01974   1.11756   1.24234
# Region 3915   0.50857  0.565529  0.713681  ...  0.460244  0.520711   0.69026
#
# [3915 rows x 15 columns]

# %%
df = df.T
print(df)
# Out:
#           Region 1  Region 2  Region 3  ... Region 3913 Region 3914 Region 3915
# Month 73  0.251694  0.226178  0.308033  ...    0.721403      1.3267     0.50857
# Month 74  0.296335  0.287932    0.3633  ...    0.767218     1.42983    0.565529
# Month 75  0.367923   0.32979  0.408197  ...    0.918551     1.40525    0.713681
# Month 76  0.299255  0.266668  0.352324  ...    0.973048     1.45046    0.731899
# Month 77  0.268446  0.255178  0.346444  ...     0.72849     1.19333    0.525591
# Month 78  0.233933  0.207229  0.299434  ...    0.673608     1.00386    0.461589
# Month 79  0.261915  0.237377  0.318974  ...    0.576971    0.952881    0.476323
# Month 80  0.303832  0.297279   0.37402  ...    0.672467     1.04011    0.537825
# Month 81  0.374387  0.339003  0.419677  ...    0.957308     1.46876    0.713446
# Month 82  0.302387  0.275986   0.36401  ...    0.962457     1.39375    0.713675
# Month 83  0.278578  0.263434  0.357895  ...     0.66504       1.208    0.506093
# ...

# %%
df.to_csv('/content/sample_data/final_output.csv')

# %%
z = results.predict(start=73,end=87,dynamic=False)
print(z)
# Out:
# 73    0.483984
# 74    0.569824
# 75    0.707482
# 76    0.575439
# 77    0.516196
# 78    0.449832
# 79    0.503639
# 80    0.584240
# 81    0.719910
# 82    0.581462
# 83    0.535679
# 84    0.468621
# 85    0.519555
# 86    0.599551
# 87    0.734992
# dtype: float64
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)

# %%
print(type(z))
print(list(z))
# Out:
# <class 'pandas.core.series.Series'>
# [0.5675088379060983, 0.596111389000932, 0.6829007974347329, 0.8198558846105914, 0.6728610825894772, 0.6119455387173105, 0.5967136293576124, 0.63403661530018, 0.7057756565644654, 0.8541582557284644, 0.6955709286028974, 0.6531496269991255, 0.6270432333984293]

# %%
print (data2.iloc[0])

# %%
import matplotlib.pyplot as plt
plt.plot(z)

# %%
plt.plot(test.iloc[0])

# %%
plt.plot(z)

# %%
def loss(test,predicted):
  n=len(test)
  sum1=0
  for x in range(n):
    sum1=sum1+((test[x]-predicted[x])**2)
  sum1=sum1/n
  return sum1

# %%
print(loss(list(test.iloc[0]), list(z)))

# %%
print("")
