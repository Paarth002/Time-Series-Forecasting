# %%
# Mounting drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Train Set - Train Set.csv')

# %%
df
# Out:
#       Region_Name   Month 1   Month 2  ...  Month 70  Month 71  Month 72
# 0        Region 1  0.154324  0.122901  ...  0.373754  0.333642  0.242176
# 1        Region 2  0.119708  0.119831  ...  0.344997  0.300503  0.215147
# 2        Region 3  0.178236  0.165497  ...  0.400269  0.360406  0.335923
# 3        Region 4  0.225016  0.220602  ...  0.364874  0.311379  0.271102
# 4        Region 5  0.318976  0.316835  ...  0.416527  0.372523  0.392835
# ...           ...       ...       ...  ...       ...       ...       ...
# 3910  Region 3911  3.400484  3.999567  ...  3.531807  3.057962  3.118734
# 3911  Region 3912  0.374751  0.478654  ...  0.972735  0.947009  0.806398
# 3912  Region 3913  0.463527  0.571315  ...  1.207824  1.147999  0.768685
# 3913  Region 3914  1.641510  1.649937  ...  1.773948  1.640214  1.489277
# 3914  Region 3915  0.307089  0.451604  ...  0.817059  0.754813  0.542317
#
# [3915 rows x 73 columns]

# %%
data = []
for x in range(0,3915):
  df1 = df.iloc[x,1:]
  data.append(df1)
data[0]
# Out:
# Month 1     0.154324
# Month 2     0.122901
# Month 3     0.127583
# Month 4     0.501557
# Month 5     0.103551
#               ...
# Month 68    0.234171
# Month 69    0.294693
# Month 70    0.373754
# Month 71    0.333642
# Month 72    0.242176
# Name: 0, Length: 72, dtype: object

# %%
df1 = df.iloc[0,1:]

# %%
df1
# Out:
# Month 1     0.154324
# Month 2     0.122901
# Month 3     0.127583
# Month 4     0.501557
# Month 5     0.103551
#               ...
# Month 68    0.234171
# Month 69    0.294693
# Month 70    0.373754
# Month 71    0.333642
# Month 72    0.242176
# Name: 0, Length: 72, dtype: object

# %%
data_modified = []
for x in range(3915):
  # print(data[x])
  l1 = []
  for z in data[x]:
    if z<=0 :
      y=0.001
    else:
      y=z
    l1.append(y)
    # print(z)
  data_modified.append(l1)
# print(len(data_modified[0]))
# data[0][0]
data_modified[0]
# Out:
# [0.15432449999999998,
#  0.122900762,
#  0.127582778,
#  0.501556809,
#  0.103551004,
#  0.051983348,
#  0.14027175,
#  0.157586219,
#  0.182546265,
#  0.18180113899999997,
#  0.001,
#  0.213958137,
#  0.20258455399999997,
#  0.256381304,
#  0.327656008,
#  0.277943595,
#  0.20062283,
#  0.141673204,
#  0.133457062,
#  0.092708141,
#  0.12422531199999999,
#  0.199408681,
#  0.21158379,
#  0.25608765699999997,
#  0.046845207,
#  0.05022351,
#  0.044738229000000004,
#  0.04960181,
#  0.185712847,
#  0.141932711,
#  0.032244437,
#  0.101613543,
#  0.202953333,
#  0.18560383600000002,
#  0.083222397,
#  0.09790355699999999,
#  0.24112034699999998,
#  0.264635835,
#  0.253286318,
#  0.422998892,
#  0.464442133,
#  0.316720277,
#  0.22431353,
#  0.33828919799999996,
#  0.37835167,
#  0.520046195,
#  0.391280342,
#  0.314726359,
#  0.27020041100000003,
#  0.362764835,
#  0.376728136,
#  0.394985834,
#  0.347692034,
#  0.351116516,
#  0.37512038,
#  0.289648674,
#  0.372379191,
# ...

# %%
import numpy as np

# %%
l1 = []
for x in df1:
  if x<=0:
    y=0.001
  else:
    y=x
  l1.append(y)
l1 = np.array(l1)
l2 = l1.reshape(-1,1)
l2
# Out:
# array([[0.1543245 ],
#        [0.12290076],
#        [0.12758278],
#        [0.50155681],
#        [0.103551  ],
#        [0.05198335],
#        [0.14027175],
#        [0.15758622],
#        [0.18254627],
#        [0.18180114],
#        [0.001     ],
#        [0.21395814],
#        [0.20258455],
#        [0.2563813 ],
#        [0.32765601],
#        [0.27794359],
#        [0.20062283],
#        [0.1416732 ],
#        [0.13345706],
#        [0.09270814],
#        [0.12422531],
#        [0.19940868],
#        [0.21158379],
#        [0.25608766],
#        [0.04684521],
#        [0.05022351],
#        [0.04473823],
#        [0.04960181],
#        [0.18571285],
#        [0.14193271],
#        [0.03224444],
#        [0.10161354],
#        [0.20295333],
#        [0.18560384],
#        [0.0832224 ],
#        [0.09790356],
#        [0.24112035],
#        [0.26463583],
#        [0.25328632],
#        [0.42299889],
#        [0.46444213],
#        [0.31672028],
#        [0.22431353],
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
train = scaler.fit_transform(l2)
final = []
for x in range(72):
  final.append(train[x][0])
final = np.array(final)
final
# Out:
# array([-0.71640556, -0.97718753, -0.93833202,  2.16523529, -1.13776894,
#        -1.56572296, -0.83302771, -0.68933693, -0.48219639, -0.4883801 ,
#        -1.98882788, -0.22151289, -0.31590094,  0.13055208,  0.72205262,
#         0.30949504, -0.33218106, -0.8213972 , -0.88958202, -1.22775261,
#        -0.96619524, -0.34225714, -0.24121732,  0.12811514, -1.6083638 ,
#        -1.58032766, -1.62584937, -1.58548707, -0.45591729, -0.81924358,
#        -1.72953391, -1.1538477 , -0.31284048, -0.45682196, -1.3064737 ,
#        -1.18463645,  0.00390316,  0.19905548,  0.10486715,  1.51329221,
#         1.85722488,  0.63129825, -0.13557468,  0.81029624,  1.14277007,
#         2.31867657,  1.25006362,  0.61475096,  0.24523525,  1.01341672,
#         1.12929655,  1.28081507,  0.88832929,  0.91674867,  1.11595397,
#         0.40663414,  1.09320515,  1.3068445 ,  1.01213422,  0.19183873,
#         0.29022802,  0.09563031,  0.79887262,  0.6736899 ,  0.67423957,
# ...

# %%
dataf = []
for x in range(3915):
  region = 'Region'+str(x+1)
  df3 = pd.DataFrame({region:data_modified[x]})
  df3['Date'] = pd.date_range(start='1/1/1979', periods=len(df3), freq='MS')
  df3 = df3.set_index('Date')
  dataf.append(df3)
dataf[0].head(20)
# Out:
#              Region1
# Date
# 1979-01-01  0.154324
# 1979-02-01  0.122901
# 1979-03-01  0.127583
# 1979-04-01  0.501557
# 1979-05-01  0.103551
# 1979-06-01  0.051983
# 1979-07-01  0.140272
# 1979-08-01  0.157586
# 1979-09-01  0.182546
# 1979-10-01  0.181801
# 1979-11-01  0.001000
# 1979-12-01  0.213958
# 1980-01-01  0.202585
# 1980-02-01  0.256381
# 1980-03-01  0.327656
# 1980-04-01  0.277944
# 1980-05-01  0.200623
# 1980-06-01  0.141673
# 1980-07-01  0.133457
# 1980-08-01  0.092708

# %%
df3 = pd.DataFrame({'Value':final})
df3
# Out:
#        Value
# 0  -0.716406
# 1  -0.977188
# 2  -0.938332
# 3   2.165235
# 4  -1.137769
# ..       ...
# 67 -0.053766
# 68  0.448493
# 69  1.104612
# 70  0.771727
# 71  0.012663
#
# [72 rows x 1 columns]

# %%
df3['Date'] = pd.date_range(start='1/1/1979', periods=len(df3), freq='MS')
df3
# Out:
#        Value       Date
# 0  -0.716406 1979-01-01
# 1  -0.977188 1979-02-01
# 2  -0.938332 1979-03-01
# 3   2.165235 1979-04-01
# 4  -1.137769 1979-05-01
# ..       ...        ...
# 67 -0.053766 1984-08-01
# 68  0.448493 1984-09-01
# 69  1.104612 1984-10-01
# 70  0.771727 1984-11-01
# 71  0.012663 1984-12-01
#
# [72 rows x 2 columns]

# %%
df3 = df3.set_index('Date')
df3
# Out:
#                Value
# Date
# 1979-01-01 -0.712301
# 1979-02-01 -0.972196
# 1979-03-01 -0.933472
# 1979-04-01  2.159529
# 1979-05-01 -1.132230
# ...              ...
# 1984-08-01 -0.051918
# 1984-09-01  0.448631
# 1984-10-01  1.102516
# 1984-11-01  0.770765
# 1984-12-01  0.014285
#
# [72 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(df3)

# %%
import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
seasonal_decompose(df3, model='mul', freq=6).plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-bd08d663392d> in <module>()
# ----> 1 seasonal_decompose(df3, model='mul', freq=6).plot()
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/seasonal.py in seasonal_decompose(x, model, filt, freq, two_sided, extrapolate_trend)
#     117     if model.startswith('m'):
#     118         if np.any(x <= 0):
# --> 119             raise ValueError("Multiplicative seasonality is not appropriate "
#     120                              "for zero and negative values")
#     121
#
# ValueError: Multiplicative seasonality is not appropriate for zero and negative values

# %%
import numpy as np

# %%
def loss(test,predicted):
  n=len(test)
  sum1=0
  for x in range(n):
    sum1=sum1+((test.Region1[x]-predicted[x])**2)
  sum1=sum1/n
  return sum1**(0.5)

# %%
params = [['add','add'], ['add','mul'], ['mul','add'],['mul','mul']]

# %%
predict = []
losses = []
for i in range(3915):
  train = dataf[i][0:61]
  test = dataf[i][61:73]
  result = []
  region = 'Region'+str(i+1)
  for j in range(4):
    model1 = ExponentialSmoothing(train['Region'+str(i+1)], trend=params[j][0], seasonal=params[j][1], seasonal_periods=6).fit()
    test_pred1 = model1.forecast(12)
    def loss(test,predicted):
      n=len(test)
      sum1=0
      for x in range(n):
        sum1=sum1+((test['Region'+str(i+1)][x]-predicted[x])**2)
      sum1=sum1/n
      return sum1**(0.5)
    result.append(loss(test,test_pred1))
  result_index = np.argmin(result)
  # result_index
  model = ExponentialSmoothing(train['Region'+str(i+1)], trend=params[result_index][0], seasonal=params[result_index][1], seasonal_periods=6).fit()
  test_pred = model.forecast(15)
  predict.append(test_pred)
  losses.append(result[result_index])
# predict
# Out:
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters.py:712: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
# ...

# %%
test = df3.iloc[61:73,]
test
# Out:
#              Region1
# Date
# 1984-02-01  0.191496
# 1984-03-01  0.283412
# 1984-04-01  0.302669
# 1984-05-01  0.306597
# 1984-06-01  0.327412
# 1984-07-01  0.124563
# 1984-08-01  0.218367
# 1984-09-01  0.275179
# 1984-10-01  0.344997
# 1984-11-01  0.300503
# 1984-12-01  0.215147

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
model = ExponentialSmoothing(train.Region1, trend='mul', seasonal='add', seasonal_periods=6).fit()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)

# %%
test_pred = model.forecast(12)
test_pred
# Out:
# 1984-02-01    0.252494
# 1984-03-01    0.311495
# 1984-04-01    0.352172
# 1984-05-01    0.279988
# 1984-06-01    0.269981
# 1984-07-01    0.234223
# 1984-08-01    0.260312
# 1984-09-01    0.319352
# 1984-10-01    0.360069
# 1984-11-01    0.287924
# 1984-12-01    0.277957
# 1985-01-01    0.242238
# Freq: MS, dtype: float64

# %%
train['Region1'].plot(legend=True, label='Train', figsize=(10,6))
test['Region1'].plot(legend=True, label='Test')
test_pred.plot(legend=True, label='Predicted_Test')

# %%
import statsmodels

# %%
df_train = df.iloc[:,1:61]
df_train
# Out:
#        Month 1   Month 2   Month 3  ...  Month 58  Month 59  Month 60
# 0     0.154324  0.122901  0.127583  ...  0.398122  0.362610  0.263766
# 1     0.119708  0.119831  0.112970  ...  0.372061  0.318767  0.221102
# 2     0.178236  0.165497  0.190754  ...  0.437532  0.401876  0.320588
# 3     0.225016  0.220602  0.224240  ...  0.432136  0.366376  0.264211
# 4     0.318976  0.316835  0.328486  ...  0.482598  0.408525  0.381367
# ...        ...       ...       ...  ...       ...       ...       ...
# 3910  3.400484  3.999567  3.308452  ...  2.861484  3.978575  3.463067
# 3911  0.374751  0.478654  0.501871  ...  0.851394  1.041560  0.809464
# 3912  0.463527  0.571315  0.644025  ...  0.975505  1.518267  1.231226
# 3913  1.641510  1.649937  2.110449  ...  1.641601  2.245675  2.113290
# 3914  0.307089  0.451604  0.448063  ...  0.670476  0.969269  0.751451
#
# [3915 rows x 60 columns]

# %%
df_test = df.iloc[:,61:]
df_test
# Out:
#       Month 61  Month 62  Month 63  ...  Month 70  Month 71  Month 72
# 0     0.275622  0.252173  0.336913  ...  0.373754  0.333642  0.242176
# 1     0.221851  0.191496  0.283412  ...  0.344997  0.300503  0.215147
# 2     0.310557  0.285627  0.331988  ...  0.400269  0.360406  0.335923
# 3     0.271887  0.248869  0.315252  ...  0.364874  0.311379  0.271102
# 4     0.336923  0.288830  0.366314  ...  0.416527  0.372523  0.392835
# ...        ...       ...       ...  ...       ...       ...       ...
# 3910  3.563363  3.455968  3.321083  ...  3.531807  3.057962  3.118734
# 3911  0.763070  0.762306  1.061902  ...  0.972735  0.947009  0.806398
# 3912  1.232993  1.127408  1.196925  ...  1.207824  1.147999  0.768685
# 3913  2.210518  1.813585  1.930428  ...  1.773948  1.640214  1.489277
# 3914  0.734620  0.663206  0.773679  ...  0.817059  0.754813  0.542317
#
# [3915 rows x 12 columns]

# %%
import statsmodels

# %%
fit = statsmodels.tsa.holtwinters.ExponentialSmoothing(endog=df_train)

# %%
fit.predict(12)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-551a8ceed0a4> in <module>()
# ----> 1 fit.predict(12)
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters.py in predict(self, params, start, end)
#     537             start=start, end=end)
#     538         if out_of_sample > 0:
# --> 539             res = self._predict(h=out_of_sample, **params)
#     540         else:
#     541             res = self._predict(h=0, **params)
#
# TypeError: _predict() argument after ** must be a mapping, not int

# %%
def loss(test,predicted):
  n=len(test)
  sum1=0
  for x in range(n):
    sum1=sum1+((test.Region1[x]-predicted[x])**2)
  sum1=sum1/n
  return sum1**(0.5)

# %%
params = [['add','add'], ['add','mul'], ['mul','add'],['mul','mul']]

# %%
result = []
for i in range(4):
  model1 = ExponentialSmoothing(train.Region1, trend=params[i][0], seasonal=params[i][1], seasonal_periods=6).fit()
  test_pred1 = model1.forecast(12)
  result.append(loss(test,test_pred1))
  # model2 = ExponentialSmoothing(train.Region1, trend='mul', seasonal='mul', seasonal_periods=6).fit()
  # test_pred2 = model2.forecast(12)
  # model3 = ExponentialSmoothing(train.Region1, trend='add', seasonal='add', seasonal_periods=6).fit()
  # test_pred3 = model3.forecast(12)
  # model4 = ExponentialSmoothing(train.Region1, trend='add', seasonal='mul', seasonal_periods=6).fit()
  # test_pred4 = model4.forecast(12)
import numpy as np
result_index = np.argmin(result)
result_index
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters.py:712: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)
# 2

# %%
model = ExponentialSmoothing(train.Region1, trend=params[result_index][0], seasonal=params[result_index][1], seasonal_periods=6).fit()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)

# %%
test_pred = model.forecast(12)
test_pred
# Out:
# 1984-02-01    0.252494
# 1984-03-01    0.311495
# 1984-04-01    0.352172
# 1984-05-01    0.279988
# 1984-06-01    0.269981
# 1984-07-01    0.234223
# 1984-08-01    0.260312
# 1984-09-01    0.319352
# 1984-10-01    0.360069
# 1984-11-01    0.287924
# 1984-12-01    0.277957
# 1985-01-01    0.242238
# Freq: MS, dtype: float64

# %%
train['Region1'].plot(legend=True, label='Train', figsize=(10,6))
test['Region1'].plot(legend=True, label='Test')
test_pred.plot(legend=True, label='Predicted_Test')

# %%
dataX, dataY = [], []
for i in range(len(n_X)-look_back):
  a = n_X[i:(i+look_back), ]
  dataX.append(a)
  dataY.append(n_X[i + look_back, ])
  return numpy.array(dataX), numpy.array(dataY)

# %%
type(predict[10][0])
# Out:
# numpy.float64

# %%
max(losses)
# Out:
# 39.666470213305374

# %%
df10 = pd.DataFrame()
df10['Month'] = ['Month '+str(x) for x in range(73,88)]
for x in range(3915):
  l10 = []
  for y in range(15):
    l10.append(float(predict[x][y]))
  df10['Region '+str(x+1)] = l10
df10
# Out:
#        Month  Region 1  Region 2  ...  Region 3913  Region 3914  Region 3915
# 0   Month 73  0.250648  0.252494  ...     1.323355     1.706361     0.825488
# 1   Month 74  0.320294  0.311495  ...     1.329780     1.903866     0.832517
# 2   Month 75  0.349778  0.352172  ...     1.503689     2.071299     0.946108
# 3   Month 76  0.320166  0.279988  ...     1.486602     1.994793     0.894001
# 4   Month 77  0.256366  0.269981  ...     1.374476     1.978809     0.782691
# 5   Month 78  0.289828  0.234223  ...     1.298742     1.608948     0.724423
# 6   Month 79  0.250648  0.260312  ...     1.398373     1.750958     0.824106
# 7   Month 80  0.320294  0.319352  ...     1.404833     1.953410     0.831136
# 8   Month 81  0.349778  0.360069  ...     1.578779     2.124967     0.944727
# 9   Month 82  0.320166  0.287924  ...     1.561727     2.046256     0.892621
# 10  Month 83  0.256366  0.277957  ...     1.449637     2.029641     0.781311
# ...

# %%
df10.to_csv('iitbtech.csv', index=False)
